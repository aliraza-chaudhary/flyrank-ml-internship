# %% [markdown]
# <a href="https://colab.research.google.com/github/aliraza-chaudhary/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/aliraza-chaudhary/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %%
# !git clone https://github.com/aliraza-chaudhary/flyrank-ml-internship.git
# %cd flyrank-ml-internship
# Out:
# Cloning into 'flyrank-ml-internship'...
# remote: Enumerating objects: 119, done.
# remote: Counting objects: 100% (119/119), done.
# remote: Compressing objects: 100% (75/75), done.
# remote: Total 119 (delta 35), reused 95 (delta 28), pack-reused 0 (from 0)
# Receiving objects: 100% (119/119), 1.84 MiB | 16.56 MiB/s, done.
# Resolving deltas: 100% (35/35), done.
# /content/flyrank-ml-internship/flyrank-ml-internship/flyrank-ml-internship/flyrank-ml-internship/flyrank-ml-internship

# %%
import os
print(os.getcwd())
# Out:
# /content/flyrank-ml-internship/flyrank-ml-internship/flyrank-ml-internship/flyrank-ml-internship/flyrank-ml-internship

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# 1. My Lane and Why
#
# Lane: Content Refresh Prioritization
#
# Why:
#
# I chose the Content Refresh Prioritization lane because websites often contain pages that lose traffic over time. It is important to identify which pages should be updated first so that time and resources are spent on the pages with the highest potential impact.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# 2. The Question
#
# Research Question
#
# Which web pages should be prioritized for content refresh to improve search performance?
#
# Decision
#
# Decide which pages should be refreshed first.
#
# Action
#
# Update the selected pages by improving their content, keywords, and structure.
#
# Cost of a Wrong Recommendation
#
# If the wrong pages are selected, time and effort are wasted while important declining pages continue to lose traffic.
#
# Why ML Can Help
#
# A machine learning model can identify patterns from historical search data that are difficult to detect using simple manual rules.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Total Pages:", len(df))

print("\nDeclining Rate:")
print(df["trend_direction"].value_counts(normalize=True))

print("\nAverage CTR:")
print(df["ctr"].mean())

print("\nAverage Word Count:")
print(df["word_count"].mean())
# Out:
# Total Pages: 30000
#
# Declining Rate:
# trend_direction
# down      0.542067
# stable    0.198733
# up        0.146267
# new       0.074533
# flat      0.038400
# Name: proportion, dtype: float64
#
# Average CTR:
# 0.5107333333333334
#
# Average Word Count:
# 3107.760324649119

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# Careful Words: What I Can and Can't Claim
#
# This project identifies patterns in historical search data to support content refresh decisions. The results should be used as decision support rather than as proof that refreshing a page will improve its search performance. I cannot claim to predict Google's algorithm or guarantee ranking improvements. Any findings are observational and directional, not causal.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.

# %% [markdown]
# ✓ Every section above is filled.
#
# ✓ The notebook runs top to bottom without errors.
#
# ✓ No client names, URLs, or private queries are included.
#
# ✓ My claims use careful language (observed, measured, directional, decision support).
#
# ✓ The notebook is committed to my GitHub repository.
